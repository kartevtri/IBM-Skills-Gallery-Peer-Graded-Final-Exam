# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Kartev Trivedi<b/>

# %% [markdown]
# Aspiring financial advisor

# %% [markdown]
# *I am interested in learning data science because I think that it is a great supplement in the financial career I have decided to pursue. Finance tackles a lot of data, which is why I want to learn how to interpret, analyze, and present said data in order to perform better at my intented career.*

# %% [markdown]
# ### My code will print "I love to box"

# %%
print("I love to box")
# Out:
# I love to box

# %% [markdown]
# |IBM Cloud|GitHub|Coursera|
# |---------------|------|--------|
# |<a href="https://cloud.ibm.com">IBM Cloud</a>|<a href="https://github.com">GitHub</a>|<a href="https://www.coursera.org">Coursera</a>|

# %% [markdown]
# ![image.png](attachment:image.png)
